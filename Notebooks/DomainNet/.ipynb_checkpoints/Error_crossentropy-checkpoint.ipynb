# %%
import pandas as pd
import os
from utils import *

# %%
res_columns = ['Calibrated on', 'clipart', 'infograph', 'painting', 'quickdraw', 'real', 'sketch', 'Average']

# %%
best_rho_er_in = best_rho_calib('Error', 'in', 'crossentropy')
best_rho_ece_in = best_rho_calib('ECE', 'in', 'crossentropy')

# %%
ece_file_in = os.path.join('..', '..', 'results', 'DomainNet', 'crossentropy', 'in_ECE_mean.csv')
ece_in = pd.read_csv(ece_file_in)
ece_in = get_res_df(ece_in, best_rho_er_in, best_rho_ece_in)

# %%
res_mean_in = ece_in[MAIN_COLUMNS+['Domain']][(ece_in['Valid'] == False) & (ece_in['Train'] == False)].groupby(['Domain']).mean().T
res_std_in = ece_in[MAIN_COLUMNS+['Domain']][(ece_in['Valid'] == False) & (ece_in['Train'] == False)].groupby(['Domain']).std().T

# %%
res_mean_in['Average'] = res_mean_in[['clipart', 'infograph', 'painting', 'quickdraw', 'real', 'sketch']].mean(axis=1)

# %%
res_std_in['std'] = get_std(res_mean_in, res_std_in)

# %%
res_mean_in = res_mean_in.round(2)
res_std_in = res_std_in.round(2)

# %%
for domain in ['clipart', 'infograph', 'painting', 'quickdraw', 'real', 'sketch']:
    res_mean_in[domain] = res_mean_in[domain].astype(str) + '+' + res_std_in[domain].astype(str)
res_mean_in['Average'] = res_mean_in['Average'].astype(str) + '+' + res_std_in['std'].astype(str)

# %%
res_mean_in['Calibrated on'] = ['in'] * len(res_mean_in)
res_mean_in.rename_axis('Method', axis='columns', inplace=True)

# %%
res_mean_in[res_columns]
# Out:
# Method            Calibrated on     clipart   infograph    painting  \
# Uncalibrated                 in   16.12+3.2   28.95+6.9  22.74+5.24
# TS Source                    in  10.98+2.83  22.31+5.58  15.39+3.99
# TS Oracle                    in   5.93+0.68   4.72+0.73   4.96+0.78
# HB                           in   7.47+0.77  13.12+2.78   7.99+2.81
# Isotonic                     in   7.11+0.82   13.17+2.4    7.5+2.66
# Beta abm                     in   7.14+1.11   11.1+2.48   6.24+1.59
# Beta am                      in    7.3+1.74  10.95+2.27    5.64+1.1
# Beta ab                      in  13.72+2.73  26.17+6.25   19.6+5.19
# TS                           in   8.02+2.54  10.35+4.34   6.07+1.48
# Cluster NN                   in   7.27+1.33  11.67+5.03    6.0+1.76
# Cluster LR                   in   8.43+1.84  13.01+7.69   6.97+2.43
# Cluster Ensem                in    7.2+1.48  11.55+5.34   5.66+1.18
# CaliGen Er                   in    9.63+1.3   6.91+1.81   5.83+0.62
# CaliGen TS Er                in    6.43+0.8  17.63+3.65   9.99+3.18
# CaliGen Ensem Er             in  11.25+2.73    7.61+2.9   5.76+1.39
# CaliGen ECE                  in  10.02+2.02   7.45+3.67   4.99+1.03
# CaliGen TS ECE               in   5.59+0.84  17.25+7.24   8.79+2.95
# CaliGen Ensem ECE            in    9.93+2.5   8.34+3.84   5.26+0.95
#
# Method               quickdraw        real      sketch      Average
# Uncalibrated       38.33+13.88  18.61+3.71   22.1+3.73  24.48+10.25
# TS Source          28.43+13.09  11.26+4.01  14.05+2.05    17.07+9.0
# TS Oracle            2.44+0.69    5.08+0.6   5.34+0.37    4.74+1.28
# HB                  18.61+4.25   7.33+1.39   7.88+1.32    10.4+4.88
# Isotonic            18.92+4.61   6.82+1.28   7.29+1.42   10.14+5.16
# Beta abm            15.73+3.35    6.5+1.19   6.08+0.95     8.8+4.06
# Beta am             14.31+3.03   6.64+1.61    5.53+0.7     8.4+3.72
# Beta ab             34.95+8.66  16.44+3.34   19.3+3.77   21.69+8.86
# TS                 18.23+11.84   9.06+3.66   6.11+1.25    9.64+6.89
# Cluster NN           19.6+8.33   6.24+1.13    6.0+1.04    9.46+6.44
# Cluster LR          21.86+7.04   7.62+2.16   6.08+0.87   10.66+7.11
# Cluster Ensem       20.27+7.61    6.3+1.61   5.23+0.57     9.37+6.6
# CaliGen Er          12.17+1.56    8.4+0.86    5.81+0.6    8.13+2.57
# CaliGen TS Er       23.12+2.25   7.17+1.99   9.46+1.76    12.3+6.53
# CaliGen Ensem Er     13.42+6.1  10.37+3.42   7.18+1.79    9.27+4.32
# CaliGen ECE         11.14+2.11   8.45+1.93   6.88+1.83    8.16+3.02
# CaliGen TS ECE      21.22+3.06    6.7+2.42   7.01+1.75   11.09+6.98
# CaliGen Ensem ECE   13.56+6.26   9.48+3.09   6.69+1.89    8.88+4.39

# %%
best_rho_er_out = best_rho_calib('Error', 'out', 'crossentropy')
best_rho_ece_out = best_rho_calib('ECE', 'out', 'crossentropy')

# %%
ece_file_out = os.path.join('..', '..', 'results', 'DomainNet', 'crossentropy', 'out_ECE_mean.csv')
ece_out = pd.read_csv(ece_file_out)
ece_out = get_res_df(ece_out, best_rho_er_out, best_rho_ece_out)

# %%
res_mean_out = ece_out[MAIN_COLUMNS+['Domain']][(ece_out['Valid'] == False) & (ece_out['Train'] == False)].groupby(['Domain']).mean().T
res_std_out = ece_out[MAIN_COLUMNS+['Domain']][(ece_out['Valid'] == False) & (ece_out['Train'] == False)].groupby(['Domain']).std().T

# %%
res_mean_out = ece_out[MAIN_COLUMNS+['Domain']][(ece_out['Valid'] == False) & (ece_out['Train'] == False)].groupby(['Domain']).mean().T
res_std_out = ece_out[MAIN_COLUMNS+['Domain']][(ece_out['Valid'] == False) & (ece_out['Train'] == False)].groupby(['Domain']).std().T

# %%
res_mean_out['Average'] = res_mean_out[['clipart', 'infograph', 'painting', 'quickdraw', 'real', 'sketch']].mean(axis=1)
res_std_out['std'] = get_std(res_mean_out, res_std_out)

# %%
res_mean_out = res_mean_out.round(2)
res_std_out = res_std_out.round(2)

# %%
for domain in ['clipart', 'infograph', 'painting', 'quickdraw', 'real', 'sketch']:
    res_mean_out[domain] = res_mean_out[domain].astype(str) + '+' + res_std_out[domain].astype(str)
res_mean_out['Average'] = res_mean_out['Average'].astype(str) + '+' + res_std_out['std'].astype(str)

# %%
res_mean_out['Calibrated on'] = ['out'] * len(res_mean_out)
res_mean_out.rename_axis('Method', axis='columns', inplace=True)

# %%
res_mean_out[res_columns]
# Out:
# Method            Calibrated on     clipart   infograph    painting  \
# Uncalibrated                out   16.12+3.2   28.95+6.9  22.74+5.24
# TS Source                   out  11.04+2.98  21.61+5.08   14.82+4.4
# TS Oracle                   out   5.93+0.68   4.72+0.73   4.96+0.78
# HB                          out   7.83+0.76  11.19+2.72   8.02+3.43
# Isotonic                    out   7.87+0.95  12.02+2.06    8.1+3.66
# Beta abm                    out   8.47+1.74   9.88+2.07   6.78+2.28
# Beta am                     out   9.07+2.64   9.03+1.94   5.46+1.04
# Beta ab                     out  13.15+2.66  25.37+6.52  18.67+5.38
# TS                          out  14.06+5.91   6.78+3.02   7.69+3.71
# Cluster NN                  out  10.43+3.15    8.26+4.1    5.29+1.4
# Cluster LR                  out   11.01+3.8   9.06+5.54   6.93+3.16
# Cluster Ensem               out  10.62+3.12   7.82+4.22    5.57+1.8
# CaliGen Er                  out    8.99+1.9   5.98+1.67    6.14+1.1
# CaliGen TS Er               out    8.7+0.71  19.39+3.68  10.78+2.16
# CaliGen Ensem Er            out  17.28+4.79   5.14+2.31  10.78+4.42
# CaliGen ECE                 out  11.96+3.76   5.06+4.21   6.59+2.54
# CaliGen TS ECE              out    6.04+1.9  16.24+7.82    8.27+2.4
# CaliGen Ensem ECE           out  16.81+5.08    5.43+3.8   9.59+5.41
#
# Method               quickdraw        real      sketch      Average
# Uncalibrated       38.33+13.88  18.61+3.71   22.1+3.73  24.48+10.25
# TS Source           28.05+13.9  11.05+4.32   14.08+2.5   16.77+9.12
# TS Oracle            2.44+0.69    5.08+0.6   5.34+0.37    4.74+1.28
# HB                  16.13+6.85    7.9+2.22    7.12+1.0      9.7+4.7
# Isotonic            17.12+7.65   7.66+1.78   6.84+0.97    9.93+5.16
# Beta abm            13.64+6.19   7.85+1.41    6.4+1.46    8.84+3.88
# Beta am             12.19+5.06    8.03+1.6   5.95+1.31    8.29+3.45
# Beta ab              31.99+5.6  15.66+3.25  18.57+3.83   20.57+7.91
# TS                  12.83+8.37  14.29+5.54   9.15+4.43    10.8+6.24
# Cluster NN          15.95+6.69   9.51+3.55   6.27+1.94    9.28+5.19
# Cluster LR          21.94+7.18   12.7+5.13    7.75+3.1    11.57+7.0
# Cluster Ensem       17.28+5.82   9.81+3.39   6.77+2.28     9.64+5.3
# CaliGen Er          10.87+1.99   8.32+1.09   5.96+1.18     7.71+2.4
# CaliGen TS Er       25.21+2.43   8.72+1.33  11.74+1.85   14.09+6.53
# CaliGen Ensem Er     9.85+4.46  17.02+3.95  11.77+3.55   11.97+5.81
# CaliGen ECE         10.15+2.78  10.72+3.08   9.61+3.68    9.02+4.16
# CaliGen TS ECE      23.74+4.33   6.46+2.66   7.65+2.87    11.4+7.72
# CaliGen Ensem ECE   10.04+4.87   16.35+5.4  11.72+4.09   11.66+6.24

# %%
res = pd.concat([res_mean_in[res_columns], res_mean_out[res_columns]])
res
# Out:
# Method            Calibrated on     clipart   infograph    painting  \
# Uncalibrated                 in   16.12+3.2   28.95+6.9  22.74+5.24
# TS Source                    in  11.04+2.98  21.61+5.08   14.82+4.4
# TS Oracle                    in   5.93+0.68   4.72+0.73   4.96+0.78
# HB                           in   7.47+0.77  13.12+2.78   7.99+2.81
# Isotonic                     in   7.11+0.82   13.17+2.4    7.5+2.66
# Beta abm                     in   7.14+1.11   11.1+2.48   6.24+1.59
# Beta am                      in    7.3+1.74  10.95+2.27    5.64+1.1
# Beta ab                      in  13.72+2.73  26.17+6.25   19.6+5.19
# TS                           in   8.02+2.54  10.35+4.34   6.07+1.48
# Cluster NN                   in    7.27+1.3  11.67+4.98    6.02+1.8
# Cluster LR                   in   8.44+1.85   13.0+7.53   6.91+2.38
# Cluster Ensem                in   7.14+1.42  11.53+5.24   5.68+1.21
# CaliGen Er                   in    9.63+1.3   6.91+1.81   5.83+0.62
# CaliGen TS Er                in    6.43+0.8  17.63+3.65   9.99+3.18
# CaliGen Ensem Er             in  11.25+2.73    7.61+2.9   5.76+1.39
# CaliGen ECE                  in  10.02+2.02   7.45+3.67   4.99+1.03
# CaliGen TS ECE               in   5.59+0.84  17.25+7.24   8.79+2.95
# CaliGen Ensem ECE            in    9.93+2.5   8.34+3.84   5.26+0.95
# Uncalibrated                out   16.12+3.2   28.95+6.9  22.74+5.24
# TS Source                   out  11.04+2.98  21.61+5.08   14.82+4.4
# TS Oracle                   out   5.93+0.68   4.72+0.73   4.96+0.78
# HB                          out   7.83+0.76  11.19+2.72   8.02+3.43
# Isotonic                    out   7.87+0.95  12.02+2.06    8.1+3.66
# Beta abm                    out   8.47+1.74   9.88+2.07   6.78+2.28
# Beta am                     out   9.07+2.64   9.03+1.94   5.46+1.04
# Beta ab                     out  13.15+2.66  25.37+6.52  18.67+5.38
# TS                          out  14.06+5.91   6.78+3.02   7.69+3.71
# Cluster NN                  out  10.43+3.15    8.26+4.1    5.29+1.4
# Cluster LR                  out   11.01+3.8   9.06+5.54   6.93+3.16
# Cluster Ensem               out  10.62+3.12   7.82+4.22    5.57+1.8
# CaliGen Er                  out    8.99+1.9   5.98+1.67    6.14+1.1
# CaliGen TS Er               out    8.7+0.71  19.39+3.68  10.78+2.16
# CaliGen Ensem Er            out  17.28+4.79   5.14+2.31  10.78+4.42
# CaliGen ECE                 out  11.96+3.76   5.06+4.21   6.59+2.54
# CaliGen TS ECE              out    6.04+1.9  16.24+7.82    8.27+2.4
# CaliGen Ensem ECE           out  16.81+5.08    5.43+3.8   9.59+5.41
#
# Method               quickdraw        real      sketch      Average
# Uncalibrated       38.33+13.88  18.61+3.71   22.1+3.73  24.48+10.25
# TS Source           28.05+13.9  11.05+4.32   14.08+2.5   16.77+9.12
# TS Oracle            2.44+0.69    5.08+0.6   5.34+0.37    4.74+1.28
# HB                  18.61+4.25   7.33+1.39   7.88+1.32    10.4+4.88
# Isotonic            18.92+4.61   6.82+1.28   7.29+1.42   10.14+5.16
# Beta abm            15.73+3.35    6.5+1.19   6.08+0.95     8.8+4.06
# Beta am             14.31+3.03   6.64+1.61    5.53+0.7     8.4+3.72
# Beta ab             34.95+8.66  16.44+3.34   19.3+3.77    21.7+8.86
# TS                 18.23+11.84   9.06+3.66   6.11+1.25    9.64+6.89
# Cluster NN          19.62+8.32   6.21+1.09     6.0+1.2    9.46+6.44
# Cluster LR          22.03+6.07   7.77+2.27   5.85+1.11    10.67+7.0
# Cluster Ensem       20.28+7.42   6.34+1.61   5.21+0.56    9.36+6.55
# CaliGen Er          12.17+1.56    8.4+0.86    5.81+0.6    8.13+2.57
# CaliGen TS Er       23.12+2.25   7.17+1.99   9.46+1.76    12.3+6.53
# CaliGen Ensem Er     13.42+6.1  10.37+3.42   7.18+1.79    9.27+4.32
# CaliGen ECE         11.14+2.11   8.45+1.93   6.88+1.83    8.16+3.02
# CaliGen TS ECE      21.22+3.06    6.7+2.42   7.01+1.75   11.09+6.98
# CaliGen Ensem ECE   13.56+6.26   9.48+3.09   6.69+1.89    8.88+4.39
# Uncalibrated       38.33+13.88  18.61+3.71   22.1+3.73  24.48+10.25
# TS Source           28.05+13.9  11.05+4.32   14.08+2.5   16.77+9.12
# TS Oracle            2.44+0.69    5.08+0.6   5.34+0.37    4.74+1.28
# HB                  16.13+6.85    7.9+2.22    7.12+1.0      9.7+4.7
# Isotonic            17.12+7.65   7.66+1.78   6.84+0.97    9.93+5.16
# Beta abm            13.64+6.19   7.85+1.41    6.4+1.46    8.84+3.88
# Beta am             12.19+5.06    8.03+1.6   5.95+1.31    8.29+3.45
# Beta ab              31.99+5.6  15.66+3.25  18.57+3.83   20.57+7.91
# TS                  12.83+8.37  14.29+5.54   9.15+4.43    10.8+6.24
# Cluster NN          15.95+6.69   9.51+3.55   6.27+1.94    9.28+5.19
# Cluster LR          21.94+7.18   12.7+5.13    7.75+3.1    11.57+7.0
# Cluster Ensem       17.28+5.82   9.81+3.39   6.77+2.28     9.64+5.3
# CaliGen Er          10.87+1.99   8.32+1.09   5.96+1.18     7.71+2.4
# CaliGen TS Er       25.21+2.43   8.72+1.33  11.74+1.85   14.09+6.53
# CaliGen Ensem Er     9.85+4.46  17.02+3.95  11.77+3.55   11.97+5.81
# CaliGen ECE         10.15+2.78  10.72+3.08   9.61+3.68    9.02+4.16
# CaliGen TS ECE      23.74+4.33   6.46+2.66   7.65+2.87    11.4+7.72
# CaliGen Ensem ECE   10.04+4.87   16.35+5.4  11.72+4.09   11.66+6.24

# %%
res_mean_in = ece_in[MAIN_COLUMNS+['Domain']][(ece_in['Train'] == True)].groupby(['Domain']).mean().T
res_std_in = ece_in[MAIN_COLUMNS+['Domain']][(ece_in['Train'] == True)].groupby(['Domain']).std().T

# %%
res_mean_in['Average'] = res_mean_in[['clipart', 'infograph', 'painting', 'quickdraw', 'real', 'sketch']].mean(axis=1)

# %%
res_std_in['std'] = get_std(res_mean_in, res_std_in)

# %%
res_mean_in = res_mean_in.round(2)
res_std_in = res_std_in.round(2)

# %%
for domain in ['clipart', 'infograph', 'painting', 'quickdraw', 'real', 'sketch']:
    res_mean_in[domain] = res_mean_in[domain].astype(str) + '+' + res_std_in[domain].astype(str)
res_mean_in['Average'] = res_mean_in['Average'].astype(str) + '+' + res_std_in['std'].astype(str)

# %%
res_mean_in['Calibrated on'] = ['in'] * len(res_mean_in)
res_mean_in.rename_axis('Method', axis='columns', inplace=True)

# %%
res_mean_in[res_columns]
# Out:
# Method            Calibrated on     clipart   infograph    painting  \
# Uncalibrated                 in   6.27+0.48    9.0+2.24   7.34+1.33
# TS Source                    in  15.01+3.51  17.12+6.46  12.99+1.74
# TS Oracle                    in   4.38+0.61   5.29+0.08   5.21+0.18
# HB                           in  15.55+1.78  15.23+3.46  14.31+2.13
# Isotonic                     in   15.5+1.82  15.12+3.65  14.43+2.04
# Beta abm                     in  18.24+1.99  18.86+4.23  18.02+1.75
# Beta am                      in  24.54+3.57    21.1+5.2  22.53+3.23
# Beta ab                      in   8.55+0.75  10.99+1.81   9.47+1.73
# TS                           in   31.82+5.4  29.22+7.68  30.57+6.41
# Cluster NN                   in   26.37+4.0  22.22+4.01  20.12+3.03
# Cluster LR                   in  24.53+3.94  19.19+3.62  18.22+2.95
# Cluster Ensem                in  26.36+3.77  23.26+4.53  21.57+2.34
# CaliGen Er                   in  22.14+1.01  15.38+2.89   19.1+1.78
# CaliGen TS Er                in    8.6+1.27   6.35+1.35   6.91+1.14
# CaliGen Ensem Er             in   31.47+3.6  26.24+5.23  29.03+3.31
# CaliGen ECE                  in   26.9+2.92  16.43+3.17  21.51+2.12
# CaliGen TS ECE               in  12.58+2.35   7.82+1.69   8.91+2.45
# CaliGen Ensem ECE            in  32.78+4.04  25.25+5.51  28.61+2.66
#
# Method              quickdraw        real      sketch     Average
# Uncalibrated        5.81+0.68    5.57+1.1   8.24+0.48   7.04+1.76
# TS Source            8.3+1.64   9.22+1.37  14.63+2.97  12.88+4.66
# TS Oracle           4.65+0.48   4.17+0.54   4.85+0.35   4.76+0.58
# HB                  9.51+1.34  11.48+1.66   15.1+2.18  13.53+3.15
# Isotonic            8.88+1.62  11.39+1.92   14.92+2.5  13.38+3.38
# Beta abm           11.01+2.12   14.2+2.12  18.01+2.76  16.39+3.87
# Beta am             14.6+3.06  19.18+4.44  21.82+3.93  20.63+5.06
# Beta ab              6.9+0.98   6.94+0.92   10.47+1.0   8.89+2.03
# TS                  20.9+4.99  23.44+6.92  29.42+5.73  27.56+7.41
# Cluster NN          8.72+2.05   16.13+1.8  24.31+4.52  19.64+6.77
# Cluster LR          8.13+1.29  14.84+1.85  21.32+3.68  17.71+6.03
# Cluster Ensem      11.14+2.23  16.95+2.17  24.19+4.17  20.58+6.11
# CaliGen Er         14.53+1.01  20.27+1.25  19.32+1.98  18.46+3.21
# CaliGen TS Er       5.37+0.28   8.18+1.24   7.25+0.84   7.11+1.53
# CaliGen Ensem Er   20.46+3.01   24.4+3.21   29.2+4.42   26.8+5.31
# CaliGen ECE        14.83+1.49  20.94+1.64  22.65+3.05   20.54+4.7
# CaliGen TS ECE       5.8+0.54   9.09+1.18   10.2+2.06   9.07+2.77
# CaliGen Ensem ECE  19.81+3.19   24.1+3.22  29.56+4.82  26.68+5.81
